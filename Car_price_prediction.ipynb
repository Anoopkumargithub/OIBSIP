# %% [markdown]
# ## Importing Necessary Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Loading Dataset
df = pd.read_csv('car_price.csv')
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df = df.drop(['car_ID'],axis = 1)

# %%
df
# Out:
#      symboling                   CarName fueltype aspiration doornumber  \
# 0            3        alfa-romero giulia      gas        std        two
# 1            3       alfa-romero stelvio      gas        std        two
# 2            1  alfa-romero Quadrifoglio      gas        std        two
# 3            2               audi 100 ls      gas        std       four
# 4            2                audi 100ls      gas        std       four
# ..         ...                       ...      ...        ...        ...
# 200         -1           volvo 145e (sw)      gas        std       four
# 201         -1               volvo 144ea      gas      turbo       four
# 202         -1               volvo 244dl      gas        std       four
# 203         -1                 volvo 246   diesel      turbo       four
# 204         -1               volvo 264gl      gas      turbo       four
#
#          carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0    convertible        rwd          front       88.6      168.8  ...
# 1    convertible        rwd          front       88.6      168.8  ...
# 2      hatchback        rwd          front       94.5      171.2  ...
# 3          sedan        fwd          front       99.8      176.6  ...
# 4          sedan        4wd          front       99.4      176.6  ...
# ..           ...        ...            ...        ...        ...  ...
# 200        sedan        rwd          front      109.1      188.8  ...
# 201        sedan        rwd          front      109.1      188.8  ...
# 202        sedan        rwd          front      109.1      188.8  ...
# 203        sedan        rwd          front      109.1      188.8  ...
# 204        sedan        rwd          front      109.1      188.8  ...
#
#      enginesize  fuelsystem  boreratio stroke compressionratio  horsepower  \
# 0           130        mpfi       3.47   2.68              9.0         111
# 1           130        mpfi       3.47   2.68              9.0         111
# 2           152        mpfi       2.68   3.47              9.0         154
# 3           109        mpfi       3.19   3.40             10.0         102
# 4           136        mpfi       3.19   3.40              8.0         115
# ..          ...         ...        ...    ...              ...         ...
# 200         141        mpfi       3.78   3.15              9.5         114
# 201         141        mpfi       3.78   3.15              8.7         160
# 202         173        mpfi       3.58   2.87              8.8         134
# 203         145         idi       3.01   3.40             23.0         106
# 204         141        mpfi       3.78   3.15              9.5         114
#
#     peakrpm  citympg  highwaympg    price
# 0      5000       21          27  13495.0
# 1      5000       21          27  16500.0
# 2      5000       19          26  16500.0
# 3      5500       24          30  13950.0
# 4      5500       18          22  17450.0
# ..      ...      ...         ...      ...
# 200    5400       23          28  16845.0
# 201    5300       19          25  19045.0
# 202    5500       18          23  21485.0
# 203    4800       26          27  22470.0
# 204    5400       19          25  22625.0
#
# [205 rows x 25 columns]

# %%
df.shape
# Out:
# (205, 25)

# %%
df.size
# Out:
# 5125

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   CarName           205 non-null    object
#  2   fueltype          205 non-null    object
#  3   aspiration        205 non-null    object
#  4   doornumber        205 non-null    object
#  5   carbody           205 non-null    object
#  6   drivewheel        205 non-null    object
#  7   enginelocation    205 non-null    object
#  8   wheelbase         205 non-null    float64
#  9   carlength         205 non-null    float64
#  10  carwidth          205 non-null    float64
#  11  carheight         205 non-null    float64
#  12  curbweight        205 non-null    int64
#  13  enginetype        205 non-null    object
#  14  cylindernumber    205 non-null    object
#  15  enginesize        205 non-null    int64
#  16  fuelsystem        205 non-null    object
#  17  boreratio         205 non-null    float64
#  18  stroke            205 non-null    float64
#  19  compressionratio  205 non-null    float64
#  20  horsepower        205 non-null    int64
#  21  peakrpm           205 non-null    int64
#  22  citympg           205 non-null    int64
#  23  highwaympg        205 non-null    int64
#  24  price             205 non-null    float64
# dtypes: float64(8), int64(7), object(10)
# memory usage: 40.2+ KB

# %%
df.describe()
# Out:
#         symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# 25%    2145.000000   97.000000    3.150000    3.110000          8.600000
# 50%    2414.000000  120.000000    3.310000    3.290000          9.000000
# 75%    2935.000000  141.000000    3.580000    3.410000          9.400000
# max    4066.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakrpm     citympg  highwaympg         price
# count  205.000000   205.000000  205.000000  205.000000    205.000000
# mean   104.117073  5125.121951   25.219512   30.751220  13276.710571
# std     39.544167   476.985643    6.542142    6.886443   7988.852332
# min     48.000000  4150.000000   13.000000   16.000000   5118.000000
# 25%     70.000000  4800.000000   19.000000   25.000000   7788.000000
# 50%     95.000000  5200.000000   24.000000   30.000000  10295.000000
# 75%    116.000000  5500.000000   30.000000   34.000000  16503.000000
# max    288.000000  6600.000000   49.000000   54.000000  45400.000000

# %%
df.isnull().sum()
# Out:
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
print("1. Fuel Type :")
print(df['fueltype'].value_counts(),"\n")
print("2.Aspiration :")
print(df['aspiration'].value_counts(),"\n")
print("3. Door Number:")
print(df['doornumber'].value_counts(),"\n")
print("4. Car Body :")
print(df['carbody'].value_counts(),"\n")
print("5. Drive Wheel :")
print(df['drivewheel'].value_counts(),"\n")
print("6. Engine Location :")
print(df['enginelocation'].value_counts(),"\n")
print("7. Engine Type :")
print(df['enginetype'].value_counts(),"\n")
print("8. Cylinder Number :")
print(df['cylindernumber'].value_counts(),"\n")
print("9. Fuel System :")
print(df['fuelsystem'].value_counts(),"\n")
# Out:
# 1. Fuel Type :
# fueltype
# gas       185
# diesel     20
# Name: count, dtype: int64
#
# 2.Aspiration :
# aspiration
# std      168
# turbo     37
# Name: count, dtype: int64
#
# 3. Door Number:
# doornumber
# four    115
# two      90
# Name: count, dtype: int64
#
# 4. Car Body :
# carbody
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64
#
# 5. Drive Wheel :
# drivewheel
# fwd    120
# rwd     76
# 4wd      9
# Name: count, dtype: int64
#
# 6. Engine Location :
# enginelocation
# front    202
# rear       3
# Name: count, dtype: int64
#
# 7. Engine Type :
# enginetype
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# Name: count, dtype: int64
#
# 8. Cylinder Number :
# cylindernumber
# four      159
# six        24
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# Name: count, dtype: int64
#
# 9. Fuel System :
# fuelsystem
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
car = ['fueltype', 'aspiration','doornumber', 'carbody', 'drivewheel', 'enginelocation','enginetype',
       'cylindernumber','fuelsystem']
for i in car:
    label_encoder = LabelEncoder()
    df[i+'_label_encoder'] = label_encoder.fit_transform(df[i])
df.drop(car,axis = 1,inplace= True)
df
# Out:
#      symboling                   CarName  wheelbase  carlength  carwidth  \
# 0            3        alfa-romero giulia       88.6      168.8      64.1
# 1            3       alfa-romero stelvio       88.6      168.8      64.1
# 2            1  alfa-romero Quadrifoglio       94.5      171.2      65.5
# 3            2               audi 100 ls       99.8      176.6      66.2
# 4            2                audi 100ls       99.4      176.6      66.4
# ..         ...                       ...        ...        ...       ...
# 200         -1           volvo 145e (sw)      109.1      188.8      68.9
# 201         -1               volvo 144ea      109.1      188.8      68.8
# 202         -1               volvo 244dl      109.1      188.8      68.9
# 203         -1                 volvo 246      109.1      188.8      68.9
# 204         -1               volvo 264gl      109.1      188.8      68.9
#
#      carheight  curbweight  enginesize  boreratio  stroke  ...    price  \
# 0         48.8        2548         130       3.47    2.68  ...  13495.0
# 1         48.8        2548         130       3.47    2.68  ...  16500.0
# 2         52.4        2823         152       2.68    3.47  ...  16500.0
# 3         54.3        2337         109       3.19    3.40  ...  13950.0
# 4         54.3        2824         136       3.19    3.40  ...  17450.0
# ..         ...         ...         ...        ...     ...  ...      ...
# 200       55.5        2952         141       3.78    3.15  ...  16845.0
# 201       55.5        3049         141       3.78    3.15  ...  19045.0
# 202       55.5        3012         173       3.58    2.87  ...  21485.0
# 203       55.5        3217         145       3.01    3.40  ...  22470.0
# 204       55.5        3062         141       3.78    3.15  ...  22625.0
#
#      fueltype_label_encoder  aspiration_label_encoder  \
# 0                         1                         0
# 1                         1                         0
# 2                         1                         0
# 3                         1                         0
# 4                         1                         0
# ..                      ...                       ...
# 200                       1                         0
# 201                       1                         1
# 202                       1                         0
# 203                       0                         1
# 204                       1                         1
#
#      doornumber_label_encoder  carbody_label_encoder  \
# 0                           1                      0
# 1                           1                      0
# 2                           1                      2
# 3                           0                      3
# 4                           0                      3
# ..                        ...                    ...
# 200                         0                      3
# 201                         0                      3
# 202                         0                      3
# 203                         0                      3
# 204                         0                      3
#
#      drivewheel_label_encoder  enginelocation_label_encoder  \
# 0                           2                             0
# 1                           2                             0
# 2                           2                             0
# 3                           1                             0
# 4                           0                             0
# ..                        ...                           ...
# 200                         2                             0
# 201                         2                             0
# 202                         2                             0
# 203                         2                             0
# 204                         2                             0
#
#      enginetype_label_encoder  cylindernumber_label_encoder  \
# 0                           0                             2
# 1                           0                             2
# 2                           5                             3
# 3                           3                             2
# 4                           3                             1
# ..                        ...                           ...
# 200                         3                             2
# 201                         3                             2
# 202                         5                             3
# 203                         3                             3
# 204                         3                             2
#
#      fuelsystem_label_encoder
# 0                           5
# 1                           5
# 2                           5
# 3                           5
# 4                           5
# ..                        ...
# 200                         5
# 201                         5
# 202                         5
# 203                         3
# 204                         5
#
# [205 rows x 25 columns]

# %%
plt.figure(figsize = (12,10))
sns.displot(df.price)
plt.show()

# %%
corr = df.corr(numeric_only = True)
corr
# Out:
#                               symboling  wheelbase  carlength  carwidth  \
# symboling                      1.000000  -0.531954  -0.357612 -0.232919
# wheelbase                     -0.531954   1.000000   0.874587  0.795144
# carlength                     -0.357612   0.874587   1.000000  0.841118
# carwidth                      -0.232919   0.795144   0.841118  1.000000
# carheight                     -0.541038   0.589435   0.491029  0.279210
# curbweight                    -0.227691   0.776386   0.877728  0.867032
# enginesize                    -0.105790   0.569329   0.683360  0.735433
# boreratio                     -0.130051   0.488750   0.606454  0.559150
# stroke                        -0.008735   0.160959   0.129533  0.182942
# compressionratio              -0.178515   0.249786   0.158414  0.181129
# horsepower                     0.070873   0.353294   0.552623  0.640732
# peakrpm                        0.273606  -0.360469  -0.287242 -0.220012
# citympg                       -0.035823  -0.470414  -0.670909 -0.642704
# highwaympg                     0.034606  -0.544082  -0.704662 -0.677218
# price                         -0.079978   0.577816   0.682920  0.759325
# fueltype_label_encoder         0.194311  -0.308346  -0.212679 -0.233880
# aspiration_label_encoder      -0.059866   0.257611   0.234539  0.300567
# doornumber_label_encoder       0.664073  -0.447357  -0.398568 -0.207168
# carbody_label_encoder         -0.596135   0.401362   0.334433  0.131710
# drivewheel_label_encoder      -0.041671   0.459745   0.485649  0.470751
# enginelocation_label_encoder   0.212471  -0.187790  -0.050989 -0.051698
# enginetype_label_encoder       0.050372  -0.135577  -0.113291  0.012298
# cylindernumber_label_encoder   0.197762  -0.184596  -0.109585 -0.194074
# fuelsystem_label_encoder       0.091163   0.384601   0.557810  0.521434
#
#                               carheight  curbweight  enginesize  boreratio  \
# symboling                     -0.541038   -0.227691   -0.105790  -0.130051
# wheelbase                      0.589435    0.776386    0.569329   0.488750
# carlength                      0.491029    0.877728    0.683360   0.606454
# carwidth                       0.279210    0.867032    0.735433   0.559150
# carheight                      1.000000    0.295572    0.067149   0.171071
# curbweight                     0.295572    1.000000    0.850594   0.648480
# enginesize                     0.067149    0.850594    1.000000   0.583774
# boreratio                      0.171071    0.648480    0.583774   1.000000
# stroke                        -0.055307    0.168790    0.203129  -0.055909
# compressionratio               0.261214    0.151362    0.028971   0.005197
# horsepower                    -0.108802    0.750739    0.809769   0.573677
# peakrpm                       -0.320411   -0.266243   -0.244660  -0.254976
# citympg                       -0.048640   -0.757414   -0.653658  -0.584532
# highwaympg                    -0.107358   -0.797465   -0.677470  -0.587012
# price                          0.119336    0.835305    0.874145   0.553173
# fueltype_label_encoder        -0.284631   -0.217275   -0.069594  -0.054451
# aspiration_label_encoder       0.087311    0.324902    0.108217   0.212614
# doornumber_label_encoder      -0.552208   -0.197379   -0.020742  -0.119258
# carbody_label_encoder          0.568534    0.128467   -0.073352   0.010549
# drivewheel_label_encoder      -0.019719    0.575111    0.524307   0.481827
# enginelocation_label_encoder  -0.106234    0.050468    0.196826   0.185042
# enginetype_label_encoder      -0.127002   -0.055265    0.040766   0.029355
# cylindernumber_label_encoder  -0.283845   -0.047127   -0.085613  -0.032844
# fuelsystem_label_encoder       0.017046    0.611642    0.514070   0.475599
#
#                                 stroke  compressionratio  ...     price  \
# symboling                    -0.008735         -0.178515  ... -0.079978
# wheelbase                     0.160959          0.249786  ...  0.577816
# carlength                     0.129533          0.158414  ...  0.682920
# carwidth                      0.182942          0.181129  ...  0.759325
# carheight                    -0.055307          0.261214  ...  0.119336
# curbweight                    0.168790          0.151362  ...  0.835305
# enginesize                    0.203129          0.028971  ...  0.874145
# boreratio                    -0.055909          0.005197  ...  0.553173
# stroke                        1.000000          0.186110  ...  0.079443
# compressionratio              0.186110          1.000000  ...  0.067984
# horsepower                    0.080940         -0.204326  ...  0.808139
# peakrpm                      -0.067964         -0.435741  ... -0.085267
# citympg                      -0.042145          0.324701  ... -0.685751
# highwaympg                   -0.043931          0.265201  ... -0.697599
# price                         0.079443          0.067984  ...  1.000000
# fueltype_label_encoder       -0.241829         -0.984356  ... -0.105679
# aspiration_label_encoder      0.222982          0.295541  ...  0.177926
# doornumber_label_encoder      0.011082         -0.177888  ... -0.031835
# carbody_label_encoder        -0.015325          0.136243  ... -0.083976
# drivewheel_label_encoder      0.071591          0.127479  ...  0.577992
# enginelocation_label_encoder -0.138455         -0.019762  ...  0.324973
# enginetype_label_encoder     -0.141918         -0.071873  ...  0.049171
# cylindernumber_label_encoder -0.050088         -0.064701  ... -0.027628
# fuelsystem_label_encoder      0.088153         -0.100786  ...  0.526823
#
#                               fueltype_label_encoder  \
# symboling                                   0.194311
# wheelbase                                  -0.308346
# carlength                                  -0.212679
# carwidth                                   -0.233880
# carheight                                  -0.284631
# curbweight                                 -0.217275
# enginesize                                 -0.069594
# boreratio                                  -0.054451
# stroke                                     -0.241829
# compressionratio                           -0.984356
# horsepower                                  0.163926
# peakrpm                                     0.476883
# citympg                                    -0.255963
# highwaympg                                 -0.191392
# price                                      -0.105679
# fueltype_label_encoder                      1.000000
# aspiration_label_encoder                   -0.401397
# doornumber_label_encoder                    0.191491
# carbody_label_encoder                      -0.147853
# drivewheel_label_encoder                   -0.132257
# enginelocation_label_encoder                0.040070
# enginetype_label_encoder                    0.082695
# cylindernumber_label_encoder                0.110617
# fuelsystem_label_encoder                    0.041529
#
#                               aspiration_label_encoder  \
# symboling                                    -0.059866
# wheelbase                                     0.257611
# carlength                                     0.234539
# carwidth                                      0.300567
# carheight                                     0.087311
# curbweight                                    0.324902
# enginesize                                    0.108217
# boreratio                                     0.212614
# stroke                                        0.222982
# compressionratio                              0.295541
# horsepower                                    0.241685
# peakrpm                                      -0.183383
# citympg                                      -0.202362
# highwaympg                                   -0.254416
# price                                         0.177926
# fueltype_label_encoder                       -0.401397
# aspiration_label_encoder                      1.000000
# doornumber_label_encoder                     -0.031792
# carbody_label_encoder                         0.063028
# drivewheel_label_encoder                      0.066465
# enginelocation_label_encoder                 -0.057191
# enginetype_label_encoder                     -0.102963
# cylindernumber_label_encoder                 -0.133119
# fuelsystem_label_encoder                      0.288086
#
#                               doornumber_label_encoder  carbody_label_encoder  \
# symboling                                     0.664073              -0.596135
# wheelbase                                    -0.447357               0.401362
# carlength                                    -0.398568               0.334433
# carwidth                                     -0.207168               0.131710
# carheight                                    -0.552208               0.568534
# curbweight                                   -0.197379               0.128467
# enginesize                                   -0.020742              -0.073352
# boreratio                                    -0.119258               0.010549
# stroke                                        0.011082              -0.015325
# compressionratio                             -0.177888               0.136243
# horsepower                                    0.126947              -0.153928
# peakrpm                                       0.247668              -0.109643
# citympg                                       0.012417               0.031697
# highwaympg                                    0.036330              -0.007170
# price                                        -0.031835              -0.083976
# fueltype_label_encoder                        0.191491              -0.147853
# aspiration_label_encoder                     -0.031792               0.063028
# doornumber_label_encoder                      1.000000              -0.680358
# carbody_label_encoder                        -0.680358               1.000000
# drivewheel_label_encoder                      0.098954              -0.155745
# enginelocation_label_encoder                  0.137757              -0.277009
# enginetype_label_encoder                      0.062431              -0.037024
# cylindernumber_label_encoder                  0.154322              -0.048408
# fuelsystem_label_encoder                      0.015519              -0.065079
#
#                               drivewheel_label_encoder  \
# symboling                                    -0.041671
# wheelbase                                     0.459745
# carlength                                     0.485649
# carwidth                                      0.470751
# carheight                                    -0.019719
# curbweight                                    0.575111
# enginesize                                    0.524307
# boreratio                                     0.481827
# stroke                                        0.071591
# compressionratio                              0.127479
# horsepower                                    0.518686
# peakrpm                                      -0.039417
# citympg                                      -0.449581
# highwaympg                                   -0.452220
# price                                         0.577992
# fueltype_label_encoder                       -0.132257
# aspiration_label_encoder                      0.066465
# doornumber_label_encoder                      0.098954
# carbody_label_encoder                        -0.155745
# drivewheel_label_encoder                      1.000000
# enginelocation_label_encoder                  0.147865
# enginetype_label_encoder                     -0.116823
# cylindernumber_label_encoder                  0.223238
# fuelsystem_label_encoder                      0.424686
#
#                               enginelocation_label_encoder  \
# symboling                                         0.212471
# wheelbase                                        -0.187790
# carlength                                        -0.050989
# carwidth                                         -0.051698
# carheight                                        -0.106234
# curbweight                                        0.050468
# enginesize                                        0.196826
# boreratio                                         0.185042
# stroke                                           -0.138455
# compressionratio                                 -0.019762
# horsepower                                        0.317839
# peakrpm                                           0.198461
# citympg                                          -0.153487
# highwaympg                                       -0.102026
# price                                             0.324973
# fueltype_label_encoder                            0.040070
# aspiration_label_encoder                         -0.057191
# doornumber_label_encoder                          0.137757
# carbody_label_encoder                            -0.277009
# drivewheel_label_encoder                          0.147865
# enginelocation_label_encoder                      1.000000
# enginetype_label_encoder                          0.114127
# cylindernumber_label_encoder                      0.135541
# fuelsystem_label_encoder                          0.105971
#
#                               enginetype_label_encoder  \
# symboling                                     0.050372
# wheelbase                                    -0.135577
# carlength                                    -0.113291
# carwidth                                      0.012298
# carheight                                    -0.127002
# curbweight                                   -0.055265
# enginesize                                    0.040766
# boreratio                                     0.029355
# stroke                                       -0.141918
# compressionratio                             -0.071873
# horsepower                                    0.010301
# peakrpm                                       0.005599
# citympg                                      -0.085004
# highwaympg                                   -0.078456
# price                                         0.049171
# fueltype_label_encoder                        0.082695
# aspiration_label_encoder                     -0.102963
# doornumber_label_encoder                      0.062431
# carbody_label_encoder                        -0.037024
# drivewheel_label_encoder                     -0.116823
# enginelocation_label_encoder                  0.114127
# enginetype_label_encoder                      1.000000
# cylindernumber_label_encoder                  0.237390
# fuelsystem_label_encoder                     -0.091787
#
#                               cylindernumber_label_encoder  \
# symboling                                         0.197762
# wheelbase                                        -0.184596
# carlength                                        -0.109585
# carwidth                                         -0.194074
# carheight                                        -0.283845
# curbweight                                       -0.047127
# enginesize                                       -0.085613
# boreratio                                        -0.032844
# stroke                                           -0.050088
# compressionratio                                 -0.064701
# horsepower                                        0.115612
# peakrpm                                           0.222731
# citympg                                          -0.126422
# highwaympg                                       -0.085897
# price                                            -0.027628
# fueltype_label_encoder                            0.110617
# aspiration_label_encoder                         -0.133119
# doornumber_label_encoder                          0.154322
# carbody_label_encoder                            -0.048408
# drivewheel_label_encoder                          0.223238
# enginelocation_label_encoder                      0.135541
# enginetype_label_encoder                          0.237390
# cylindernumber_label_encoder                      1.000000
# fuelsystem_label_encoder                          0.011970
#
#                               fuelsystem_label_encoder
# symboling                                     0.091163
# wheelbase                                     0.384601
# carlength                                     0.557810
# carwidth                                      0.521434
# carheight                                     0.017046
# curbweight                                    0.611642
# enginesize                                    0.514070
# boreratio                                     0.475599
# stroke                                        0.088153
# compressionratio                             -0.100786
# horsepower                                    0.655638
# peakrpm                                       0.014261
# citympg                                      -0.671581
# highwaympg                                   -0.645659
# price                                         0.526823
# fueltype_label_encoder                        0.041529
# aspiration_label_encoder                      0.288086
# doornumber_label_encoder                      0.015519
# carbody_label_encoder                        -0.065079
# drivewheel_label_encoder                      0.424686
# enginelocation_label_encoder                  0.105971
# enginetype_label_encoder                     -0.091787
# cylindernumber_label_encoder                  0.011970
# fuelsystem_label_encoder                      1.000000
#
# [24 rows x 24 columns]

# %%
plt.figure(figsize = (15,14))
sns.heatmap(corr,annot=True)
plt.title("Correlation Between Columns")
# Out:
# Text(0.5, 1.0, 'Correlation Between Columns')

# %%
x = df.drop(columns = ['price','CarName'],axis=1)
y = df['price']
print(x.shape,y.shape)
# Out:
# (205, 23) (205,)

# %%
x
# Out:
#      symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0            3       88.6      168.8      64.1       48.8        2548
# 1            3       88.6      168.8      64.1       48.8        2548
# 2            1       94.5      171.2      65.5       52.4        2823
# 3            2       99.8      176.6      66.2       54.3        2337
# 4            2       99.4      176.6      66.4       54.3        2824
# ..         ...        ...        ...       ...        ...         ...
# 200         -1      109.1      188.8      68.9       55.5        2952
# 201         -1      109.1      188.8      68.8       55.5        3049
# 202         -1      109.1      188.8      68.9       55.5        3012
# 203         -1      109.1      188.8      68.9       55.5        3217
# 204         -1      109.1      188.8      68.9       55.5        3062
#
#      enginesize  boreratio  stroke  compressionratio  ...  highwaympg  \
# 0           130       3.47    2.68               9.0  ...          27
# 1           130       3.47    2.68               9.0  ...          27
# 2           152       2.68    3.47               9.0  ...          26
# 3           109       3.19    3.40              10.0  ...          30
# 4           136       3.19    3.40               8.0  ...          22
# ..          ...        ...     ...               ...  ...         ...
# 200         141       3.78    3.15               9.5  ...          28
# 201         141       3.78    3.15               8.7  ...          25
# 202         173       3.58    2.87               8.8  ...          23
# 203         145       3.01    3.40              23.0  ...          27
# 204         141       3.78    3.15               9.5  ...          25
#
#      fueltype_label_encoder  aspiration_label_encoder  \
# 0                         1                         0
# 1                         1                         0
# 2                         1                         0
# 3                         1                         0
# 4                         1                         0
# ..                      ...                       ...
# 200                       1                         0
# 201                       1                         1
# 202                       1                         0
# 203                       0                         1
# 204                       1                         1
#
#      doornumber_label_encoder  carbody_label_encoder  \
# 0                           1                      0
# 1                           1                      0
# 2                           1                      2
# 3                           0                      3
# 4                           0                      3
# ..                        ...                    ...
# 200                         0                      3
# 201                         0                      3
# 202                         0                      3
# 203                         0                      3
# 204                         0                      3
#
#      drivewheel_label_encoder  enginelocation_label_encoder  \
# 0                           2                             0
# 1                           2                             0
# 2                           2                             0
# 3                           1                             0
# 4                           0                             0
# ..                        ...                           ...
# 200                         2                             0
# 201                         2                             0
# 202                         2                             0
# 203                         2                             0
# 204                         2                             0
#
#      enginetype_label_encoder  cylindernumber_label_encoder  \
# 0                           0                             2
# 1                           0                             2
# 2                           5                             3
# 3                           3                             2
# 4                           3                             1
# ..                        ...                           ...
# 200                         3                             2
# 201                         3                             2
# 202                         5                             3
# 203                         3                             3
# 204                         3                             2
#
#      fuelsystem_label_encoder
# 0                           5
# 1                           5
# 2                           5
# 3                           5
# 4                           5
# ..                        ...
# 200                         5
# 201                         5
# 202                         5
# 203                         3
# 204                         5
#
# [205 rows x 23 columns]

# %%
y
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
print("Training Data")
print('X_train')
X_train
# Out:
# Training Data
# X_train
#      symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 66           0      104.9      175.0      66.1       54.4        2700
# 111          0      107.9      186.7      68.4       56.7        3075
# 153          0       95.7      169.7      63.6       59.1        2280
# 96           1       94.5      165.3      63.8       54.5        1971
# 38           0       96.5      167.5      65.2       53.3        2289
# ..         ...        ...        ...       ...        ...         ...
# 106          1       99.2      178.5      67.9       49.7        3139
# 14           1      103.5      189.0      66.9       55.7        3055
# 92           1       94.5      165.3      63.8       54.5        1938
# 179          3      102.9      183.5      67.7       52.0        3016
# 102          0      100.4      184.6      66.5       56.1        3296
#
#      enginesize  boreratio  stroke  compressionratio  ...  highwaympg  \
# 66          134       3.43    3.64              22.0  ...          39
# 111         120       3.46    2.19               8.4  ...          24
# 153          92       3.05    3.03               9.0  ...          37
# 96           97       3.15    3.29               9.4  ...          37
# 38          110       3.15    3.58               9.0  ...          33
# ..          ...        ...     ...               ...  ...         ...
# 106         181       3.43    3.27               9.0  ...          25
# 14          164       3.31    3.19               9.0  ...          25
# 92           97       3.15    3.29               9.4  ...          37
# 179         171       3.27    3.35               9.3  ...          24
# 102         181       3.43    3.27               9.0  ...          22
#
#      fueltype_label_encoder  aspiration_label_encoder  \
# 66                        0                         0
# 111                       1                         0
# 153                       1                         0
# 96                        1                         0
# 38                        1                         0
# ..                      ...                       ...
# 106                       1                         0
# 14                        1                         0
# 92                        1                         0
# 179                       1                         0
# 102                       1                         0
#
#      doornumber_label_encoder  carbody_label_encoder  \
# 66                          0                      3
# 111                         0                      3
# 153                         0                      4
# 96                          0                      3
# 38                          1                      2
# ..                        ...                    ...
# 106                         1                      2
# 14                          0                      3
# 92                          0                      3
# 179                         1                      2
# 102                         0                      4
#
#      drivewheel_label_encoder  enginelocation_label_encoder  \
# 66                          2                             0
# 111                         2                             0
# 153                         1                             0
# 96                          1                             0
# 38                          1                             0
# ..                        ...                           ...
# 106                         2                             0
# 14                          2                             0
# 92                          1                             0
# 179                         2                             0
# 102                         1                             0
#
#      enginetype_label_encoder  cylindernumber_label_encoder  \
# 66                          3                             2
# 111                         2                             2
# 153                         3                             2
# 96                          3                             2
# 38                          3                             2
# ..                        ...                           ...
# 106                         5                             3
# 14                          3                             3
# 92                          3                             2
# 179                         0                             3
# 102                         5                             3
#
#      fuelsystem_label_encoder
# 66                          3
# 111                         5
# 153                         1
# 96                          1
# 38                          0
# ..                        ...
# 106                         5
# 14                          5
# 92                          1
# 179                         5
# 102                         5
#
# [164 rows x 23 columns]

# %%
print("Y_train")
Y_train
# Out:
# Y_train
# 66     18344.0
# 111    15580.0
# 153     6918.0
# 96      7499.0
# 38      9095.0
#         ...
# 106    18399.0
# 14     24565.0
# 92      6849.0
# 179    15998.0
# 102    14399.0
# Name: price, Length: 164, dtype: float64

# %%
print('Testing Data')
print('X_test')
X_test
# Out:
# Testing Data
# X_test
#      symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 15           0      103.5      189.0      66.9       55.7        3230
# 9            0       99.5      178.2      67.9       52.0        3053
# 100          0       97.2      173.4      65.2       54.7        2302
# 132          3       99.1      186.6      66.5       56.1        2658
# 68          -1      110.0      190.9      70.3       58.7        3750
# 95           1       94.5      165.6      63.8       53.3        2028
# 159          0       95.7      166.3      64.4       52.8        2275
# 162          0       95.7      166.3      64.4       52.8        2140
# 147          0       97.0      173.5      65.4       53.0        2455
# 182          2       97.3      171.7      65.5       55.7        2261
# 191          0      100.4      180.2      66.9       55.1        2661
# 164          1       94.5      168.7      64.0       52.6        2204
# 65           0      104.9      175.0      66.1       54.4        2670
# 175         -1      102.4      175.6      66.5       53.9        2414
# 73           0      120.9      208.1      71.7       56.7        3900
# 152          1       95.7      158.7      63.6       54.5        2015
# 18           2       88.4      141.1      60.3       53.2        1488
# 82           3       95.9      173.2      66.3       50.2        2833
# 86           1       96.3      172.4      65.4       51.6        2405
# 143          0       97.2      172.0      65.4       52.5        2340
# 60           0       98.8      177.8      66.5       55.5        2410
# 101          0      100.4      181.7      66.5       55.1        3095
# 98           2       95.1      162.4      63.8       53.3        2008
# 30           2       86.6      144.6      63.9       50.8        1713
# 25           1       93.7      157.3      63.8       50.6        1989
# 16           0      103.5      193.8      67.9       53.7        3380
# 168          2       98.4      176.2      65.6       52.0        2536
# 195         -1      104.3      188.8      67.2       57.5        3034
# 97           1       94.5      170.2      63.8       53.5        2037
# 194         -2      104.3      188.8      67.2       56.2        2912
# 67          -1      110.0      190.9      70.3       56.5        3515
# 120          1       93.7      157.3      63.8       50.6        1967
# 154          0       95.7      169.7      63.6       59.1        2290
# 202         -1      109.1      188.8      68.9       55.5        3012
# 79           1       93.0      157.3      63.8       50.8        2145
# 69           0      106.7      187.5      70.3       54.9        3495
# 145          0       97.0      172.0      65.4       54.3        2510
# 55           3       95.3      169.0      65.7       49.6        2380
# 45           0       94.5      155.9      63.6       52.0        1909
# 84           3       95.9      173.2      66.3       50.2        2926
# 146          0       97.0      173.5      65.4       53.0        2290
#
#      enginesize  boreratio  stroke  compressionratio  ...  highwaympg  \
# 15          209       3.62   3.390              8.00  ...          22
# 9           131       3.13   3.400              7.00  ...          22
# 100         120       3.33   3.470              8.50  ...          34
# 132         121       3.54   3.070              9.31  ...          28
# 68          183       3.58   3.640             21.50  ...          25
# 95           97       3.15   3.290              9.40  ...          37
# 159         110       3.27   3.350             22.50  ...          47
# 162          98       3.19   3.030              9.00  ...          34
# 147         108       3.62   2.640              9.00  ...          31
# 182          97       3.01   3.400             23.00  ...          46
# 191         136       3.19   3.400              8.50  ...          24
# 164          98       3.19   3.030              9.00  ...          34
# 65          140       3.76   3.160              8.00  ...          27
# 175         122       3.31   3.540              8.70  ...          32
# 73          308       3.80   3.350              8.00  ...          16
# 152          92       3.05   3.030              9.00  ...          38
# 18           61       2.91   3.030              9.50  ...          53
# 82          156       3.58   3.860              7.00  ...          24
# 86          122       3.35   3.460              8.50  ...          32
# 143         108       3.62   2.640              9.00  ...          32
# 60          122       3.39   3.390              8.60  ...          32
# 101         181       3.43   3.270              9.00  ...          22
# 98           97       3.15   3.290              9.40  ...          37
# 30           92       2.91   3.410              9.60  ...          54
# 25           90       2.97   3.230              9.40  ...          38
# 16          209       3.62   3.390              8.00  ...          22
# 168         146       3.62   3.500              9.30  ...          30
# 195         141       3.78   3.150              9.50  ...          28
# 97           97       3.15   3.290              9.40  ...          37
# 194         141       3.78   3.150              9.50  ...          28
# 67          183       3.58   3.640             21.50  ...          25
# 120          90       2.97   3.230              9.40  ...          38
# 154          92       3.05   3.030              9.00  ...          32
# 202         173       3.58   2.870              8.80  ...          23
# 79           98       3.03   3.390              7.60  ...          30
# 69          183       3.58   3.640             21.50  ...          25
# 145         108       3.62   2.640              7.70  ...          29
# 55           70       3.33   3.255              9.40  ...          23
# 45           90       3.03   3.110              9.60  ...          43
# 84          156       3.59   3.860              7.00  ...          24
# 146         108       3.62   2.640              9.00  ...          32
#
#      fueltype_label_encoder  aspiration_label_encoder  \
# 15                        1                         0
# 9                         1                         1
# 100                       1                         0
# 132                       1                         0
# 68                        0                         1
# 95                        1                         0
# 159                       0                         0
# 162                       1                         0
# 147                       1                         0
# 182                       0                         0
# 191                       1                         0
# 164                       1                         0
# 65                        1                         0
# 175                       1                         0
# 73                        1                         0
# 152                       1                         0
# 18                        1                         0
# 82                        1                         1
# 86                        1                         0
# 143                       1                         0
# 60                        1                         0
# 101                       1                         0
# 98                        1                         0
# 30                        1                         0
# 25                        1                         0
# 16                        1                         0
# 168                       1                         0
# 195                       1                         0
# 97                        1                         0
# 194                       1                         0
# 67                        0                         1
# 120                       1                         0
# 154                       1                         0
# 202                       1                         0
# 79                        1                         1
# 69                        0                         1
# 145                       1                         1
# 55                        1                         0
# 45                        1                         0
# 84                        1                         1
# 146                       1                         0
#
#      doornumber_label_encoder  carbody_label_encoder  \
# 15                          0                      3
# 9                           1                      2
# 100                         0                      3
# 132                         1                      2
# 68                          0                      4
# 95                          1                      2
# 159                         0                      2
# 162                         0                      3
# 147                         0                      4
# 182                         1                      3
# 191                         0                      3
# 164                         1                      2
# 65                          0                      3
# 175                         0                      2
# 73                          0                      3
# 152                         0                      2
# 18                          1                      2
# 82                          1                      2
# 86                          0                      3
# 143                         0                      3
# 60                          0                      3
# 101                         0                      3
# 98                          1                      1
# 30                          1                      2
# 25                          0                      3
# 16                          1                      3
# 168                         1                      1
# 195                         0                      4
# 97                          0                      4
# 194                         0                      3
# 67                          0                      3
# 120                         0                      2
# 154                         0                      4
# 202                         0                      3
# 79                          1                      2
# 69                          1                      1
# 145                         0                      3
# 55                          1                      2
# 45                          0                      3
# 84                          1                      2
# 146                         0                      4
#
#      drivewheel_label_encoder  enginelocation_label_encoder  \
# 15                          2                             0
# 9                           0                             0
# 100                         1                             0
# 132                         1                             0
# 68                          2                             0
# 95                          1                             0
# 159                         1                             0
# 162                         1                             0
# 147                         1                             0
# 182                         1                             0
# 191                         1                             0
# 164                         2                             0
# 65                          2                             0
# 175                         1                             0
# 73                          2                             0
# 152                         1                             0
# 18                          1                             0
# 82                          1                             0
# 86                          1                             0
# 143                         1                             0
# 60                          1                             0
# 101                         1                             0
# 98                          1                             0
# 30                          1                             0
# 25                          1                             0
# 16                          2                             0
# 168                         2                             0
# 195                         2                             0
# 97                          1                             0
# 194                         2                             0
# 67                          2                             0
# 120                         1                             0
# 154                         0                             0
# 202                         2                             0
# 79                          1                             0
# 69                          2                             0
# 145                         0                             0
# 55                          2                             0
# 45                          1                             0
# 84                          1                             0
# 146                         1                             0
#
#      enginetype_label_encoder  cylindernumber_label_encoder  \
# 15                          3                             3
# 9                           3                             1
# 100                         3                             2
# 132                         3                             2
# 68                          3                             1
# 95                          3                             2
# 159                         3                             2
# 162                         3                             2
# 147                         4                             2
# 182                         3                             2
# 191                         3                             1
# 164                         3                             2
# 65                          3                             2
# 175                         3                             2
# 73                          5                             0
# 152                         3                             2
# 18                          2                             4
# 82                          3                             2
# 86                          3                             2
# 143                         4                             2
# 60                          3                             2
# 101                         5                             3
# 98                          3                             2
# 30                          3                             2
# 25                          3                             2
# 16                          3                             3
# 168                         3                             2
# 195                         3                             2
# 97                          3                             2
# 194                         3                             2
# 67                          3                             1
# 120                         3                             2
# 154                         3                             2
# 202                         5                             3
# 79                          3                             2
# 69                          3                             1
# 145                         4                             2
# 55                          6                             6
# 45                          3                             2
# 84                          3                             2
# 146                         4                             2
#
#      fuelsystem_label_encoder
# 15                          5
# 9                           5
# 100                         1
# 132                         5
# 68                          3
# 95                          1
# 159                         3
# 162                         1
# 147                         5
# 182                         3
# 191                         5
# 164                         1
# 65                          5
# 175                         5
# 73                          5
# 152                         1
# 18                          1
# 82                          6
# 86                          1
# 143                         5
# 60                          1
# 101                         5
# 98                          1
# 30                          0
# 25                          1
# 16                          5
# 168                         5
# 195                         5
# 97                          1
# 194                         5
# 67                          3
# 120                         1
# 154                         1
# 202                         5
# 79                          6
# 69                          3
# 145                         5
# 55                          2
# 45                          1
# 84                          6
# 146                         1
#
# [41 rows x 23 columns]

# %%
print("Y_test")
Y_test
# Out:
# Y_test
# 15     30760.000
# 9      17859.167
# 100     9549.000
# 132    11850.000
# 68     28248.000
# 95      7799.000
# 159     7788.000
# 162     9258.000
# 147    10198.000
# 182     7775.000
# 191    13295.000
# 164     8238.000
# 65     18280.000
# 175     9988.000
# 73     40960.000
# 152     6488.000
# 18      5151.000
# 82     12629.000
# 86      8189.000
# 143     9960.000
# 60      8495.000
# 101    13499.000
# 98      8249.000
# 30      6479.000
# 25      6692.000
# 16     41315.000
# 168     9639.000
# 195    13415.000
# 97      7999.000
# 194    12940.000
# 67     25552.000
# 120     6229.000
# 154     7898.000
# 202    21485.000
# 79      7689.000
# 69     28176.000
# 145    11259.000
# 55     10945.000
# 45      8916.500
# 84     14489.000
# 146     7463.000
# Name: price, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model1 = LinearRegression()

# %%
model1.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
training_data_prediction = model1.predict(X_train)
testing_data_prediction = model1.predict(X_test)

# %%
from sklearn import metrics
from sklearn.metrics import r2_score

# %%
error_score = metrics.r2_score(Y_train,training_data_prediction)
print("R squared error :",error_score)
# Out:
# R squared error : 0.8965265035488765

# %%
error_score = metrics.r2_score(Y_test,testing_data_prediction)
print("R squared error :",error_score)
# Out:
# R squared error : 0.7983838478445068

# %%
plt.scatter(Y_train,training_data_prediction)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual Price v/s Predicted Price')
# Out:
# Text(0.5, 1.0, 'Actual Price v/s Predicted Price')

# %%
plt.scatter(Y_test,testing_data_prediction)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual Price v/s Predicted Price')
# Out:
# Text(0.5, 1.0, 'Actual Price v/s Predicted Price')
